# %% [markdown]
# # # Classifiers comparison: decision trees and k-nearest neighbors on the dataset Iris
#
#
# In the following program we compare the prediction results obtained by decision trees and k-nearest neighbors on the dataset Iris

# %% [markdown]
# The following cell shows the program training a decision tree and its results in preciction

# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score # will be used to separate training and test
iris = load_iris()
clf = tree.DecisionTreeClassifier(criterion="entropy",random_state=300,min_samples_leaf=5,class_weight={0:1,1:1,2:1})
clf = clf.fit(iris.data, iris.target)
scores = cross_val_score(clf, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# Out:
# [0.96666667 1.         0.86666667 0.86666667 1.        ]

# %% [markdown]
# The following cell shows the training of k-nearest neighbors and its prediction results.
# Here we use a uniform weighting setting (weights='uniform'): any neighbors weights the same in the majority voting aggregation.

# %%
from sklearn import neighbors
n_neighbors = 11
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')
clf_knn = clf_knn.fit(iris.data, iris.target)
scores = cross_val_score(clf_knn, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# shows the model predictions
for i in range(len(iris.target)):
    print(iris.data[i,:])
    print(iris.data[i,:].reshape(1,-1))
    instance=iris.data[i,:].reshape(1,-1) # reshape(1,-1) necessary for predicţ with knn
                                          # reshape(1,-1) for one single sample, reshape(-1,1) for single feature
    #print(clf_knn.predict(instance))
    predicted=clf_knn.predict(instance)[0]
    print(predicted)
    if iris.target[i]==predicted:
        print(str(i)+" ok "+str(iris.target_names[iris.target[i]]))
    else:
        print(str(i)+" nok "+"true class: "+str(iris.target_names[iris.target[i]])+"; predicted: "+str(iris.target_names[predicted]))
# Out:
# [0.93333333 1.         1.         0.96666667 1.        ]
# [5.1 3.5 1.4 0.2]
# [[5.1 3.5 1.4 0.2]]
# 0
# 0 ok setosa
# [4.9 3.  1.4 0.2]
# [[4.9 3.  1.4 0.2]]
# 0
# 1 ok setosa
# [4.7 3.2 1.3 0.2]
# [[4.7 3.2 1.3 0.2]]
# 0
# 2 ok setosa
# [4.6 3.1 1.5 0.2]
# [[4.6 3.1 1.5 0.2]]
# 0
# 3 ok setosa
# [5.  3.6 1.4 0.2]
# [[5.  3.6 1.4 0.2]]
# 0
# 4 ok setosa
# [5.4 3.9 1.7 0.4]
# [[5.4 3.9 1.7 0.4]]
# 0
# 5 ok setosa
# [4.6 3.4 1.4 0.3]
# [[4.6 3.4 1.4 0.3]]
# 0
# 6 ok setosa
# [5.  3.4 1.5 0.2]
# [[5.  3.4 1.5 0.2]]
# 0
# 7 ok setosa
# [4.4 2.9 1.4 0.2]
# [[4.4 2.9 1.4 0.2]]
# 0
# 8 ok setosa
# [4.9 3.1 1.5 0.1]
# [[4.9 3.1 1.5 0.1]]
# 0
# 9 ok setosa
# [5.4 3.7 1.5 0.2]
# [[5.4 3.7 1.5 0.2]]
# 0
# 10 ok setosa
# [4.8 3.4 1.6 0.2]
# [[4.8 3.4 1.6 0.2]]
# 0
# 11 ok setosa
# [4.8 3.  1.4 0.1]
# [[4.8 3.  1.4 0.1]]
# 0
# 12 ok setosa
# [4.3 3.  1.1 0.1]
# [[4.3 3.  1.1 0.1]]
# 0
# 13 ok setosa
# [5.8 4.  1.2 0.2]
# [[5.8 4.  1.2 0.2]]
# 0
# 14 ok setosa
# [5.7 4.4 1.5 0.4]
# [[5.7 4.4 1.5 0.4]]
# 0
# 15 ok setosa
# [5.4 3.9 1.3 0.4]
# [[5.4 3.9 1.3 0.4]]
# 0
# 16 ok setosa
# [5.1 3.5 1.4 0.3]
# [[5.1 3.5 1.4 0.3]]
# 0
# 17 ok setosa
# [5.7 3.8 1.7 0.3]
# [[5.7 3.8 1.7 0.3]]
# 0
# 18 ok setosa
# [5.1 3.8 1.5 0.3]
# [[5.1 3.8 1.5 0.3]]
# 0
# 19 ok setosa
# [5.4 3.4 1.7 0.2]
# [[5.4 3.4 1.7 0.2]]
# 0
# 20 ok setosa
# [5.1 3.7 1.5 0.4]
# [[5.1 3.7 1.5 0.4]]
# 0
# 21 ok setosa
# [4.6 3.6 1.  0.2]
# [[4.6 3.6 1.  0.2]]
# 0
# 22 ok setosa
# [5.1 3.3 1.7 0.5]
# [[5.1 3.3 1.7 0.5]]
# 0
# 23 ok setosa
# [4.8 3.4 1.9 0.2]
# [[4.8 3.4 1.9 0.2]]
# 0
# 24 ok setosa
# [5.  3.  1.6 0.2]
# [[5.  3.  1.6 0.2]]
# 0
# 25 ok setosa
# [5.  3.4 1.6 0.4]
# [[5.  3.4 1.6 0.4]]
# 0
# 26 ok setosa
# [5.2 3.5 1.5 0.2]
# [[5.2 3.5 1.5 0.2]]
# 0
# 27 ok setosa
# [5.2 3.4 1.4 0.2]
# [[5.2 3.4 1.4 0.2]]
# 0
# 28 ok setosa
# [4.7 3.2 1.6 0.2]
# [[4.7 3.2 1.6 0.2]]
# 0
# 29 ok setosa
# [4.8 3.1 1.6 0.2]
# [[4.8 3.1 1.6 0.2]]
# 0
# 30 ok setosa
# [5.4 3.4 1.5 0.4]
# [[5.4 3.4 1.5 0.4]]
# 0
# 31 ok setosa
# [5.2 4.1 1.5 0.1]
# [[5.2 4.1 1.5 0.1]]
# 0
# 32 ok setosa
# [5.5 4.2 1.4 0.2]
# [[5.5 4.2 1.4 0.2]]
# 0
# 33 ok setosa
# [4.9 3.1 1.5 0.2]
# [[4.9 3.1 1.5 0.2]]
# 0
# 34 ok setosa
# [5.  3.2 1.2 0.2]
# [[5.  3.2 1.2 0.2]]
# 0
# 35 ok setosa
# [5.5 3.5 1.3 0.2]
# [[5.5 3.5 1.3 0.2]]
# 0
# 36 ok setosa
# [4.9 3.6 1.4 0.1]
# [[4.9 3.6 1.4 0.1]]
# 0
# 37 ok setosa
# [4.4 3.  1.3 0.2]
# [[4.4 3.  1.3 0.2]]
# 0
# 38 ok setosa
# [5.1 3.4 1.5 0.2]
# [[5.1 3.4 1.5 0.2]]
# 0
# 39 ok setosa
# [5.  3.5 1.3 0.3]
# [[5.  3.5 1.3 0.3]]
# 0
# 40 ok setosa
# [4.5 2.3 1.3 0.3]
# [[4.5 2.3 1.3 0.3]]
# 0
# 41 ok setosa
# [4.4 3.2 1.3 0.2]
# [[4.4 3.2 1.3 0.2]]
# 0
# 42 ok setosa
# [5.  3.5 1.6 0.6]
# [[5.  3.5 1.6 0.6]]
# 0
# 43 ok setosa
# [5.1 3.8 1.9 0.4]
# [[5.1 3.8 1.9 0.4]]
# 0
# 44 ok setosa
# [4.8 3.  1.4 0.3]
# [[4.8 3.  1.4 0.3]]
# 0
# 45 ok setosa
# [5.1 3.8 1.6 0.2]
# [[5.1 3.8 1.6 0.2]]
# 0
# 46 ok setosa
# [4.6 3.2 1.4 0.2]
# [[4.6 3.2 1.4 0.2]]
# 0
# 47 ok setosa
# [5.3 3.7 1.5 0.2]
# [[5.3 3.7 1.5 0.2]]
# 0
# 48 ok setosa
# [5.  3.3 1.4 0.2]
# [[5.  3.3 1.4 0.2]]
# 0
# 49 ok setosa
# [7.  3.2 4.7 1.4]
# [[7.  3.2 4.7 1.4]]
# 1
# 50 ok versicolor
# [6.4 3.2 4.5 1.5]
# [[6.4 3.2 4.5 1.5]]
# 1
# 51 ok versicolor
# [6.9 3.1 4.9 1.5]
# [[6.9 3.1 4.9 1.5]]
# 1
# 52 ok versicolor
# [5.5 2.3 4.  1.3]
# [[5.5 2.3 4.  1.3]]
# 1
# 53 ok versicolor
# [6.5 2.8 4.6 1.5]
# [[6.5 2.8 4.6 1.5]]
# 1
# 54 ok versicolor
# [5.7 2.8 4.5 1.3]
# [[5.7 2.8 4.5 1.3]]
# 1
# 55 ok versicolor
# [6.3 3.3 4.7 1.6]
# [[6.3 3.3 4.7 1.6]]
# 1
# 56 ok versicolor
# [4.9 2.4 3.3 1. ]
# [[4.9 2.4 3.3 1. ]]
# 1
# 57 ok versicolor
# [6.6 2.9 4.6 1.3]
# [[6.6 2.9 4.6 1.3]]
# 1
# 58 ok versicolor
# [5.2 2.7 3.9 1.4]
# [[5.2 2.7 3.9 1.4]]
# 1
# 59 ok versicolor
# [5.  2.  3.5 1. ]
# [[5.  2.  3.5 1. ]]
# 1
# 60 ok versicolor
# [5.9 3.  4.2 1.5]
# [[5.9 3.  4.2 1.5]]
# 1
# 61 ok versicolor
# [6.  2.2 4.  1. ]
# [[6.  2.2 4.  1. ]]
# 1
# 62 ok versicolor
# [6.1 2.9 4.7 1.4]
# [[6.1 2.9 4.7 1.4]]
# 1
# 63 ok versicolor
# [5.6 2.9 3.6 1.3]
# [[5.6 2.9 3.6 1.3]]
# 1
# 64 ok versicolor
# [6.7 3.1 4.4 1.4]
# [[6.7 3.1 4.4 1.4]]
# 1
# 65 ok versicolor
# [5.6 3.  4.5 1.5]
# [[5.6 3.  4.5 1.5]]
# 1
# 66 ok versicolor
# [5.8 2.7 4.1 1. ]
# [[5.8 2.7 4.1 1. ]]
# 1
# 67 ok versicolor
# [6.2 2.2 4.5 1.5]
# [[6.2 2.2 4.5 1.5]]
# 1
# 68 ok versicolor
# [5.6 2.5 3.9 1.1]
# [[5.6 2.5 3.9 1.1]]
# 1
# 69 ok versicolor
# [5.9 3.2 4.8 1.8]
# [[5.9 3.2 4.8 1.8]]
# 1
# 70 ok versicolor
# [6.1 2.8 4.  1.3]
# [[6.1 2.8 4.  1.3]]
# 1
# 71 ok versicolor
# [6.3 2.5 4.9 1.5]
# [[6.3 2.5 4.9 1.5]]
# 1
# 72 ok versicolor
# [6.1 2.8 4.7 1.2]
# [[6.1 2.8 4.7 1.2]]
# 1
# 73 ok versicolor
# [6.4 2.9 4.3 1.3]
# [[6.4 2.9 4.3 1.3]]
# 1
# 74 ok versicolor
# [6.6 3.  4.4 1.4]
# [[6.6 3.  4.4 1.4]]
# 1
# 75 ok versicolor
# [6.8 2.8 4.8 1.4]
# [[6.8 2.8 4.8 1.4]]
# 1
# 76 ok versicolor
# [6.7 3.  5.  1.7]
# [[6.7 3.  5.  1.7]]
# 2
# 77 nok true class: versicolor; predicted: virginica
# [6.  2.9 4.5 1.5]
# [[6.  2.9 4.5 1.5]]
# 1
# 78 ok versicolor
# [5.7 2.6 3.5 1. ]
# [[5.7 2.6 3.5 1. ]]
# 1
# 79 ok versicolor
# [5.5 2.4 3.8 1.1]
# [[5.5 2.4 3.8 1.1]]
# 1
# 80 ok versicolor
# [5.5 2.4 3.7 1. ]
# [[5.5 2.4 3.7 1. ]]
# 1
# 81 ok versicolor
# [5.8 2.7 3.9 1.2]
# [[5.8 2.7 3.9 1.2]]
# 1
# 82 ok versicolor
# [6.  2.7 5.1 1.6]
# [[6.  2.7 5.1 1.6]]
# 2
# 83 nok true class: versicolor; predicted: virginica
# [5.4 3.  4.5 1.5]
# [[5.4 3.  4.5 1.5]]
# 1
# 84 ok versicolor
# [6.  3.4 4.5 1.6]
# [[6.  3.4 4.5 1.6]]
# 1
# 85 ok versicolor
# [6.7 3.1 4.7 1.5]
# [[6.7 3.1 4.7 1.5]]
# 1
# 86 ok versicolor
# [6.3 2.3 4.4 1.3]
# [[6.3 2.3 4.4 1.3]]
# 1
# 87 ok versicolor
# [5.6 3.  4.1 1.3]
# [[5.6 3.  4.1 1.3]]
# 1
# 88 ok versicolor
# [5.5 2.5 4.  1.3]
# [[5.5 2.5 4.  1.3]]
# 1
# 89 ok versicolor
# [5.5 2.6 4.4 1.2]
# [[5.5 2.6 4.4 1.2]]
# 1
# 90 ok versicolor
# [6.1 3.  4.6 1.4]
# [[6.1 3.  4.6 1.4]]
# 1
# 91 ok versicolor
# [5.8 2.6 4.  1.2]
# [[5.8 2.6 4.  1.2]]
# 1
# 92 ok versicolor
# [5.  2.3 3.3 1. ]
# [[5.  2.3 3.3 1. ]]
# 1
# 93 ok versicolor
# [5.6 2.7 4.2 1.3]
# [[5.6 2.7 4.2 1.3]]
# 1
# 94 ok versicolor
# [5.7 3.  4.2 1.2]
# [[5.7 3.  4.2 1.2]]
# 1
# 95 ok versicolor
# [5.7 2.9 4.2 1.3]
# [[5.7 2.9 4.2 1.3]]
# 1
# 96 ok versicolor
# [6.2 2.9 4.3 1.3]
# [[6.2 2.9 4.3 1.3]]
# 1
# 97 ok versicolor
# [5.1 2.5 3.  1.1]
# [[5.1 2.5 3.  1.1]]
# 1
# 98 ok versicolor
# [5.7 2.8 4.1 1.3]
# [[5.7 2.8 4.1 1.3]]
# 1
# 99 ok versicolor
# [6.3 3.3 6.  2.5]
# [[6.3 3.3 6.  2.5]]
# 2
# 100 ok virginica
# [5.8 2.7 5.1 1.9]
# [[5.8 2.7 5.1 1.9]]
# 2
# 101 ok virginica
# [7.1 3.  5.9 2.1]
# [[7.1 3.  5.9 2.1]]
# 2
# 102 ok virginica
# [6.3 2.9 5.6 1.8]
# [[6.3 2.9 5.6 1.8]]
# 2
# 103 ok virginica
# [6.5 3.  5.8 2.2]
# [[6.5 3.  5.8 2.2]]
# 2
# 104 ok virginica
# [7.6 3.  6.6 2.1]
# [[7.6 3.  6.6 2.1]]
# 2
# 105 ok virginica
# [4.9 2.5 4.5 1.7]
# [[4.9 2.5 4.5 1.7]]
# 1
# 106 nok true class: virginica; predicted: versicolor
# [7.3 2.9 6.3 1.8]
# [[7.3 2.9 6.3 1.8]]
# 2
# 107 ok virginica
# [6.7 2.5 5.8 1.8]
# [[6.7 2.5 5.8 1.8]]
# 2
# 108 ok virginica
# [7.2 3.6 6.1 2.5]
# [[7.2 3.6 6.1 2.5]]
# 2
# 109 ok virginica
# [6.5 3.2 5.1 2. ]
# [[6.5 3.2 5.1 2. ]]
# 2
# 110 ok virginica
# [6.4 2.7 5.3 1.9]
# [[6.4 2.7 5.3 1.9]]
# 2
# 111 ok virginica
# [6.8 3.  5.5 2.1]
# [[6.8 3.  5.5 2.1]]
# 2
# 112 ok virginica
# [5.7 2.5 5.  2. ]
# [[5.7 2.5 5.  2. ]]
# 2
# 113 ok virginica
# [5.8 2.8 5.1 2.4]
# [[5.8 2.8 5.1 2.4]]
# 2
# 114 ok virginica
# [6.4 3.2 5.3 2.3]
# [[6.4 3.2 5.3 2.3]]
# 2
# 115 ok virginica
# [6.5 3.  5.5 1.8]
# [[6.5 3.  5.5 1.8]]
# 2
# 116 ok virginica
# [7.7 3.8 6.7 2.2]
# [[7.7 3.8 6.7 2.2]]
# 2
# 117 ok virginica
# [7.7 2.6 6.9 2.3]
# [[7.7 2.6 6.9 2.3]]
# 2
# 118 ok virginica
# [6.  2.2 5.  1.5]
# [[6.  2.2 5.  1.5]]
# 2
# 119 ok virginica
# [6.9 3.2 5.7 2.3]
# [[6.9 3.2 5.7 2.3]]
# 2
# 120 ok virginica
# [5.6 2.8 4.9 2. ]
# [[5.6 2.8 4.9 2. ]]
# 2
# 121 ok virginica
# [7.7 2.8 6.7 2. ]
# [[7.7 2.8 6.7 2. ]]
# 2
# 122 ok virginica
# [6.3 2.7 4.9 1.8]
# [[6.3 2.7 4.9 1.8]]
# 2
# 123 ok virginica
# [6.7 3.3 5.7 2.1]
# [[6.7 3.3 5.7 2.1]]
# 2
# 124 ok virginica
# [7.2 3.2 6.  1.8]
# [[7.2 3.2 6.  1.8]]
# 2
# 125 ok virginica
# [6.2 2.8 4.8 1.8]
# [[6.2 2.8 4.8 1.8]]
# 2
# 126 ok virginica
# [6.1 3.  4.9 1.8]
# [[6.1 3.  4.9 1.8]]
# 2
# 127 ok virginica
# [6.4 2.8 5.6 2.1]
# [[6.4 2.8 5.6 2.1]]
# 2
# 128 ok virginica
# [7.2 3.  5.8 1.6]
# [[7.2 3.  5.8 1.6]]
# 2
# 129 ok virginica
# [7.4 2.8 6.1 1.9]
# [[7.4 2.8 6.1 1.9]]
# 2
# 130 ok virginica
# [7.9 3.8 6.4 2. ]
# [[7.9 3.8 6.4 2. ]]
# 2
# 131 ok virginica
# [6.4 2.8 5.6 2.2]
# [[6.4 2.8 5.6 2.2]]
# 2
# 132 ok virginica
# [6.3 2.8 5.1 1.5]
# [[6.3 2.8 5.1 1.5]]
# 2
# 133 ok virginica
# [6.1 2.6 5.6 1.4]
# [[6.1 2.6 5.6 1.4]]
# 2
# 134 ok virginica
# [7.7 3.  6.1 2.3]
# [[7.7 3.  6.1 2.3]]
# 2
# 135 ok virginica
# [6.3 3.4 5.6 2.4]
# [[6.3 3.4 5.6 2.4]]
# 2
# 136 ok virginica
# [6.4 3.1 5.5 1.8]
# [[6.4 3.1 5.5 1.8]]
# 2
# 137 ok virginica
# [6.  3.  4.8 1.8]
# [[6.  3.  4.8 1.8]]
# 1
# 138 nok true class: virginica; predicted: versicolor
# [6.9 3.1 5.4 2.1]
# [[6.9 3.1 5.4 2.1]]
# 2
# 139 ok virginica
# [6.7 3.1 5.6 2.4]
# [[6.7 3.1 5.6 2.4]]
# 2
# 140 ok virginica
# [6.9 3.1 5.1 2.3]
# [[6.9 3.1 5.1 2.3]]
# 2
# 141 ok virginica
# [5.8 2.7 5.1 1.9]
# [[5.8 2.7 5.1 1.9]]
# 2
# 142 ok virginica
# [6.8 3.2 5.9 2.3]
# [[6.8 3.2 5.9 2.3]]
# 2
# 143 ok virginica
# [6.7 3.3 5.7 2.5]
# [[6.7 3.3 5.7 2.5]]
# 2
# 144 ok virginica
# [6.7 3.  5.2 2.3]
# [[6.7 3.  5.2 2.3]]
# 2
# 145 ok virginica
# [6.3 2.5 5.  1.9]
# [[6.3 2.5 5.  1.9]]
# 2
# 146 ok virginica
# [6.5 3.  5.2 2. ]
# [[6.5 3.  5.2 2. ]]
# 2
# 147 ok virginica
# [6.2 3.4 5.4 2.3]
# [[6.2 3.4 5.4 2.3]]
# 2
# 148 ok virginica
# [5.9 3.  5.1 1.8]
# [[5.9 3.  5.1 1.8]]
# 2
# 149 ok virginica

# %% [markdown]
# In the following cell we use a varying weighting setting (weights='distance'): any neighbors weights inversely with its distance to the test instance in the majority voting aggregation.

# %%
n_neighbors = 11
clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf_knn2.fit(iris.data, iris.target)

for i in range(len(iris.target)):
    instance=(iris.data[i,:]).reshape(1, -1)
    predicted2=clf_knn2.predict(instance)[0]
    if iris.target[i]==predicted2:
        print(str(i)+" ok "+str(iris.target_names[iris.target[i]]))
    else:
        print(str(i)+" nok "+"true class: "+str(iris.target_names[iris.target[i]])+"; predicted: "+str(iris.target_names[predicted]))
print("Classification score of k-nn with distance weighting")
scores2 = cross_val_score(clf_knn2, iris.data, iris.target, cv=5,scoring='accuracy') # score will be the accuracy
print(scores2)
# Out:
# 0 ok setosa
# 1 ok setosa
# 2 ok setosa
# 3 ok setosa
# 4 ok setosa
# 5 ok setosa
# 6 ok setosa
# 7 ok setosa
# 8 ok setosa
# 9 ok setosa
# 10 ok setosa
# 11 ok setosa
# 12 ok setosa
# 13 ok setosa
# 14 ok setosa
# 15 ok setosa
# 16 ok setosa
# 17 ok setosa
# 18 ok setosa
# 19 ok setosa
# 20 ok setosa
# 21 ok setosa
# 22 ok setosa
# 23 ok setosa
# 24 ok setosa
# 25 ok setosa
# 26 ok setosa
# 27 ok setosa
# 28 ok setosa
# 29 ok setosa
# 30 ok setosa
# 31 ok setosa
# 32 ok setosa
# 33 ok setosa
# 34 ok setosa
# 35 ok setosa
# 36 ok setosa
# 37 ok setosa
# 38 ok setosa
# 39 ok setosa
# 40 ok setosa
# 41 ok setosa
# 42 ok setosa
# 43 ok setosa
# 44 ok setosa
# 45 ok setosa
# 46 ok setosa
# 47 ok setosa
# 48 ok setosa
# 49 ok setosa
# 50 ok versicolor
# 51 ok versicolor
# 52 ok versicolor
# 53 ok versicolor
# 54 ok versicolor
# 55 ok versicolor
# 56 ok versicolor
# 57 ok versicolor
# 58 ok versicolor
# 59 ok versicolor
# 60 ok versicolor
# 61 ok versicolor
# 62 ok versicolor
# 63 ok versicolor
# 64 ok versicolor
# 65 ok versicolor
# 66 ok versicolor
# 67 ok versicolor
# 68 ok versicolor
# 69 ok versicolor
# 70 ok versicolor
# 71 ok versicolor
# 72 ok versicolor
# 73 ok versicolor
# 74 ok versicolor
# 75 ok versicolor
# 76 ok versicolor
# 77 ok versicolor
# 78 ok versicolor
# 79 ok versicolor
# 80 ok versicolor
# 81 ok versicolor
# 82 ok versicolor
# 83 ok versicolor
# 84 ok versicolor
# 85 ok versicolor
# 86 ok versicolor
# 87 ok versicolor
# 88 ok versicolor
# 89 ok versicolor
# 90 ok versicolor
# 91 ok versicolor
# 92 ok versicolor
# 93 ok versicolor
# 94 ok versicolor
# 95 ok versicolor
# 96 ok versicolor
# 97 ok versicolor
# 98 ok versicolor
# 99 ok versicolor
# 100 ok virginica
# 101 ok virginica
# 102 ok virginica
# 103 ok virginica
# 104 ok virginica
# 105 ok virginica
# 106 ok virginica
# 107 ok virginica
# 108 ok virginica
# 109 ok virginica
# 110 ok virginica
# 111 ok virginica
# 112 ok virginica
# 113 ok virginica
# 114 ok virginica
# 115 ok virginica
# 116 ok virginica
# 117 ok virginica
# 118 ok virginica
# 119 ok virginica
# 120 ok virginica
# 121 ok virginica
# 122 ok virginica
# 123 ok virginica
# 124 ok virginica
# 125 ok virginica
# 126 ok virginica
# 127 ok virginica
# 128 ok virginica
# 129 ok virginica
# 130 ok virginica
# 131 ok virginica
# 132 ok virginica
# 133 ok virginica
# 134 ok virginica
# 135 ok virginica
# 136 ok virginica
# 137 ok virginica
# 138 ok virginica
# 139 ok virginica
# 140 ok virginica
# 141 ok virginica
# 142 ok virginica
# 143 ok virginica
# 144 ok virginica
# 145 ok virginica
# 146 ok virginica
# 147 ok virginica
# 148 ok virginica
# 149 ok virginica
# Classification score of k-nn with distance weighting
# [0.96666667 1.         1.         0.96666667 1.        ]

# %% [markdown]
# The following cell shows the tuning of the k-nn models with a varying value of k (number of nearest neighbors) and finds the best value of k (giving the maximum accuracy).

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

best_accuracy=0
best_k=1
A=np.zeros(len(y_train), dtype=np.float) # for storing accuracies
for n_neighbors in np.arange(1,len(y_train)+1):
    clf_knn3 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
    # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
    clf_knn3.fit(X_train, y_train)
    index=n_neighbors-1
    A[index]=clf_knn3.score(X_test, y_test)
    if best_accuracy<clf_knn3.score(X_test, y_test):
        best_accuracy=clf_knn3.score(X_test, y_test)
        best_k=n_neighbors
    print("k neighbors="+str(n_neighbors))
    print("accuracy="+str(clf_knn3.score(X_test, y_test)))

print("\n")
print("best k="+str(best_k))
print("best accuracy="+str(best_accuracy))

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#plt.xticks(np.arange(1, len(y_train)+1, 8))
plt.yticks(np.arange(0.0,1.0,0.01))

plt.plot(np.arange(1,len(y_train)+1),A)

plt.show()
# Out:
# <ipython-input-6-73615e406c51>:12: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   A=np.zeros(len(y_train), dtype=np.float) # for storing accuracies
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.9166666666666666
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9166666666666666
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9333333333333333
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.9666666666666667
# k neighbors=13
# accuracy=0.9666666666666667
# k neighbors=14
# accuracy=0.95
# k neighbors=15
# accuracy=0.95
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9166666666666666
# k neighbors=19
# accuracy=0.9166666666666666
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9166666666666666
# k neighbors=22
# accuracy=0.9166666666666666
# k neighbors=23
# accuracy=0.9166666666666666
# k neighbors=24
# accuracy=0.9
# k neighbors=25
# accuracy=0.9166666666666666
# k neighbors=26
# accuracy=0.9166666666666666
# k neighbors=27
# accuracy=0.9333333333333333
# k neighbors=28
# accuracy=0.9333333333333333
# k neighbors=29
# accuracy=0.9333333333333333
# k neighbors=30
# accuracy=0.9166666666666666
# k neighbors=31
# accuracy=0.9333333333333333
# k neighbors=32
# accuracy=0.9166666666666666
# k neighbors=33
# accuracy=0.9333333333333333
# k neighbors=34
# accuracy=0.9166666666666666
# k neighbors=35
# accuracy=0.9333333333333333
# k neighbors=36
# accuracy=0.9166666666666666
# k neighbors=37
# accuracy=0.9333333333333333
# k neighbors=38
# accuracy=0.9
# k neighbors=39
# accuracy=0.9166666666666666
# k neighbors=40
# accuracy=0.9166666666666666
# k neighbors=41
# accuracy=0.9333333333333333
# k neighbors=42
# accuracy=0.9333333333333333
# k neighbors=43
# accuracy=0.9333333333333333
# k neighbors=44
# accuracy=0.9166666666666666
# k neighbors=45
# accuracy=0.9333333333333333
# k neighbors=46
# accuracy=0.9166666666666666
# k neighbors=47
# accuracy=0.9166666666666666
# k neighbors=48
# accuracy=0.9166666666666666
# k neighbors=49
# accuracy=0.9166666666666666
# k neighbors=50
# accuracy=0.9166666666666666
# k neighbors=51
# accuracy=0.9333333333333333
# k neighbors=52
# accuracy=0.9333333333333333
# k neighbors=53
# accuracy=0.9333333333333333
# k neighbors=54
# accuracy=0.9333333333333333
# k neighbors=55
# accuracy=0.9333333333333333
# k neighbors=56
# accuracy=0.95
# k neighbors=57
# accuracy=0.95
# k neighbors=58
# accuracy=0.95
# k neighbors=59
# accuracy=0.95
# k neighbors=60
# accuracy=0.95
# k neighbors=61
# accuracy=0.95
# k neighbors=62
# accuracy=0.95
# k neighbors=63
# accuracy=0.95
# k neighbors=64
# accuracy=0.95
# k neighbors=65
# accuracy=0.95
# k neighbors=66
# accuracy=0.95
# k neighbors=67
# accuracy=0.95
# k neighbors=68
# accuracy=0.95
# k neighbors=69
# accuracy=0.95
# k neighbors=70
# accuracy=0.95
# k neighbors=71
# accuracy=0.95
# k neighbors=72
# accuracy=0.95
# k neighbors=73
# accuracy=0.95
# k neighbors=74
# accuracy=0.95
# k neighbors=75
# accuracy=0.95
# k neighbors=76
# accuracy=0.95
# k neighbors=77
# accuracy=0.95
# k neighbors=78
# accuracy=0.95
# k neighbors=79
# accuracy=0.95
# k neighbors=80
# accuracy=0.95
# k neighbors=81
# accuracy=0.95
# k neighbors=82
# accuracy=0.95
# k neighbors=83
# accuracy=0.95
# k neighbors=84
# accuracy=0.95
# k neighbors=85
# accuracy=0.95
# k neighbors=86
# accuracy=0.95
# k neighbors=87
# accuracy=0.95
# k neighbors=88
# accuracy=0.95
# k neighbors=89
# accuracy=0.95
# k neighbors=90
# accuracy=0.95
#
#
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# In the following cell we plot in the same plot two subplots with the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

i=0  #parameter in the control of the subplot to draw on'
f,(ax1, ax2) = plt.subplots(1, 2, sharey=True)
for weight_type in ['uniform','distance']:
    print("weighting:"+str(weight_type))
    A=np.zeros(len(y_train), dtype=np.float) # for storing accuracies
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1
        A[index]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        print("k neighbors="+str(n_neighbors))
        print("accuracy="+str(clf_knn2.score(X_test, y_test)))

    print("\n")
    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    if i==0:
        ax1.plot(np.arange(1,len(y_train)+1),A)
        ax1.set_title('weighting type:'+str(weight_type))
    else:
        ax2.plot(np.arange(1,len(y_train)+1),A)
        ax2.set_title('weighting type:'+str(weight_type))
    i=i+1

plt.show()
# Out:
# weighting:uniform
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.8833333333333333
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9166666666666666
# k neighbors=7
# <ipython-input-8-679814ccc22b>:16: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   A=np.zeros(len(y_train), dtype=np.float) # for storing accuracies
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.95
# k neighbors=13
# accuracy=0.95
# k neighbors=14
# accuracy=0.9166666666666666
# k neighbors=15
# accuracy=0.9333333333333333
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9333333333333333
# k neighbors=19
# accuracy=0.9333333333333333
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9333333333333333
# k neighbors=22
# accuracy=0.9
# k neighbors=23
# accuracy=0.9
# k neighbors=24
# accuracy=0.8833333333333333
# k neighbors=25
# accuracy=0.8666666666666667
# k neighbors=26
# accuracy=0.8833333333333333
# k neighbors=27
# accuracy=0.9
# k neighbors=28
# accuracy=0.8833333333333333
# k neighbors=29
# accuracy=0.9
# k neighbors=30
# accuracy=0.8666666666666667
# k neighbors=31
# accuracy=0.9
# k neighbors=32
# accuracy=0.8666666666666667
# k neighbors=33
# accuracy=0.8833333333333333
# k neighbors=34
# accuracy=0.8666666666666667
# k neighbors=35
# accuracy=0.8833333333333333
# k neighbors=36
# accuracy=0.8666666666666667
# k neighbors=37
# accuracy=0.8833333333333333
# k neighbors=38
# accuracy=0.8666666666666667
# k neighbors=39
# accuracy=0.8666666666666667
# k neighbors=40
# accuracy=0.8666666666666667
# k neighbors=41
# accuracy=0.8333333333333334
# k neighbors=42
# accuracy=0.8166666666666667
# k neighbors=43
# accuracy=0.8166666666666667
# k neighbors=44
# accuracy=0.8166666666666667
# k neighbors=45
# accuracy=0.85
# k neighbors=46
# accuracy=0.8333333333333334
# k neighbors=47
# accuracy=0.85
# k neighbors=48
# accuracy=0.85
# k neighbors=49
# accuracy=0.85
# k neighbors=50
# accuracy=0.85
# k neighbors=51
# accuracy=0.8333333333333334
# k neighbors=52
# accuracy=0.8166666666666667
# k neighbors=53
# accuracy=0.8333333333333334
# k neighbors=54
# accuracy=0.8333333333333334
# k neighbors=55
# accuracy=0.8
# k neighbors=56
# accuracy=0.8
# k neighbors=57
# accuracy=0.8
# k neighbors=58
# accuracy=0.7833333333333333
# k neighbors=59
# accuracy=0.7666666666666667
# k neighbors=60
# accuracy=0.7666666666666667
# k neighbors=61
# accuracy=0.7666666666666667
# k neighbors=62
# accuracy=0.75
# k neighbors=63
# accuracy=0.75
# k neighbors=64
# accuracy=0.75
# k neighbors=65
# accuracy=0.75
# k neighbors=66
# accuracy=0.75
# k neighbors=67
# accuracy=0.75
# k neighbors=68
# accuracy=0.75
# k neighbors=69
# accuracy=0.75
# k neighbors=70
# accuracy=0.7333333333333333
# k neighbors=71
# accuracy=0.7333333333333333
# k neighbors=72
# accuracy=0.7333333333333333
# k neighbors=73
# accuracy=0.7333333333333333
# k neighbors=74
# accuracy=0.7166666666666667
# k neighbors=75
# accuracy=0.7166666666666667
# k neighbors=76
# accuracy=0.6833333333333333
# k neighbors=77
# accuracy=0.6666666666666666
# k neighbors=78
# accuracy=0.6333333333333333
# k neighbors=79
# accuracy=0.6333333333333333
# k neighbors=80
# accuracy=0.6
# k neighbors=81
# accuracy=0.6
# k neighbors=82
# accuracy=0.6
# k neighbors=83
# accuracy=0.6
# k neighbors=84
# accuracy=0.6
# k neighbors=85
# accuracy=0.26666666666666666
# k neighbors=86
# accuracy=0.26666666666666666
# k neighbors=87
# accuracy=0.26666666666666666
# k neighbors=88
# accuracy=0.26666666666666666
# k neighbors=89
# accuracy=0.26666666666666666
# k neighbors=90
# accuracy=0.26666666666666666
#
#
# best k=7
# best accuracy=0.9666666666666667
# weighting:distance
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.9166666666666666
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9166666666666666
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9333333333333333
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.9666666666666667
# k neighbors=13
# accuracy=0.9666666666666667
# k neighbors=14
# accuracy=0.95
# k neighbors=15
# accuracy=0.95
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9166666666666666
# k neighbors=19
# <ipython-input-8-679814ccc22b>:16: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   A=np.zeros(len(y_train), dtype=np.float) # for storing accuracies
# accuracy=0.9166666666666666
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9166666666666666
# k neighbors=22
# accuracy=0.9166666666666666
# k neighbors=23
# accuracy=0.9166666666666666
# k neighbors=24
# accuracy=0.9
# k neighbors=25
# accuracy=0.9166666666666666
# k neighbors=26
# accuracy=0.9166666666666666
# k neighbors=27
# accuracy=0.9333333333333333
# k neighbors=28
# accuracy=0.9333333333333333
# k neighbors=29
# accuracy=0.9333333333333333
# k neighbors=30
# accuracy=0.9166666666666666
# k neighbors=31
# accuracy=0.9333333333333333
# k neighbors=32
# accuracy=0.9166666666666666
# k neighbors=33
# accuracy=0.9333333333333333
# k neighbors=34
# accuracy=0.9166666666666666
# k neighbors=35
# accuracy=0.9333333333333333
# k neighbors=36
# accuracy=0.9166666666666666
# k neighbors=37
# accuracy=0.9333333333333333
# k neighbors=38
# accuracy=0.9
# k neighbors=39
# accuracy=0.9166666666666666
# k neighbors=40
# accuracy=0.9166666666666666
# k neighbors=41
# accuracy=0.9333333333333333
# k neighbors=42
# accuracy=0.9333333333333333
# k neighbors=43
# accuracy=0.9333333333333333
# k neighbors=44
# accuracy=0.9166666666666666
# k neighbors=45
# accuracy=0.9333333333333333
# k neighbors=46
# accuracy=0.9166666666666666
# k neighbors=47
# accuracy=0.9166666666666666
# k neighbors=48
# accuracy=0.9166666666666666
# k neighbors=49
# accuracy=0.9166666666666666
# k neighbors=50
# accuracy=0.9166666666666666
# k neighbors=51
# accuracy=0.9333333333333333
# k neighbors=52
# accuracy=0.9333333333333333
# k neighbors=53
# accuracy=0.9333333333333333
# k neighbors=54
# accuracy=0.9333333333333333
# k neighbors=55
# accuracy=0.9333333333333333
# k neighbors=56
# accuracy=0.95
# k neighbors=57
# accuracy=0.95
# k neighbors=58
# accuracy=0.95
# k neighbors=59
# accuracy=0.95
# k neighbors=60
# accuracy=0.95
# k neighbors=61
# accuracy=0.95
# k neighbors=62
# accuracy=0.95
# k neighbors=63
# accuracy=0.95
# k neighbors=64
# accuracy=0.95
# k neighbors=65
# accuracy=0.95
# k neighbors=66
# accuracy=0.95
# k neighbors=67
# accuracy=0.95
# k neighbors=68
# accuracy=0.95
# k neighbors=69
# accuracy=0.95
# k neighbors=70
# accuracy=0.95
# k neighbors=71
# accuracy=0.95
# k neighbors=72
# accuracy=0.95
# k neighbors=73
# accuracy=0.95
# k neighbors=74
# accuracy=0.95
# k neighbors=75
# accuracy=0.95
# k neighbors=76
# accuracy=0.95
# k neighbors=77
# accuracy=0.95
# k neighbors=78
# accuracy=0.95
# k neighbors=79
# accuracy=0.95
# k neighbors=80
# accuracy=0.95
# k neighbors=81
# accuracy=0.95
# k neighbors=82
# accuracy=0.95
# k neighbors=83
# accuracy=0.95
# k neighbors=84
# accuracy=0.95
# k neighbors=85
# accuracy=0.95
# k neighbors=86
# accuracy=0.95
# k neighbors=87
# accuracy=0.95
# k neighbors=88
# accuracy=0.95
# k neighbors=89
# accuracy=0.95
# k neighbors=90
# accuracy=0.95
#
#
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# In the following cell we plot (overlapping) in the same picture both the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

fig = plt.figure()
fig.suptitle('Accuracy in k-nn with number of neighbors and types of weighting', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
ax.set_xlabel('n. neighbors')
ax.set_ylabel('accuracy')

A=np.zeros((len(y_train),2), dtype=np.float) # 2 arrays for storing accuracies for each type of weigthing
i=0  #parameter in the control of the different diagram (=matrix A column index)
best_accuracy=0
for weight_type in ['uniform','distance']:
    print("\n weighting:"+str(weight_type))
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1 # computes the matrix row index
        A[index,i]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        print("k neighbors="+str(n_neighbors))
        print("accuracy="+str(clf_knn2.score(X_test, y_test)))

    print("\n")
    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    plt.plot(np.arange(1,len(y_train)+1),A[:,i])
    i=i+1
plt.legend(['uniform', 'distance'], loc='lower left')
plt.show()
# Out:
# <ipython-input-7-83b7b4f903f8>:18: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   A=np.zeros((len(y_train),2), dtype=np.float) # 2 arrays for storing accuracies for each type of weigthing
#  weighting:uniform
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.8833333333333333
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9166666666666666
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.95
# k neighbors=13
# accuracy=0.95
# k neighbors=14
# accuracy=0.9166666666666666
# k neighbors=15
# accuracy=0.9333333333333333
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9333333333333333
# k neighbors=19
# accuracy=0.9333333333333333
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9333333333333333
# k neighbors=22
# accuracy=0.9
# k neighbors=23
# accuracy=0.9
# k neighbors=24
# accuracy=0.8833333333333333
# k neighbors=25
# accuracy=0.8666666666666667
# k neighbors=26
# accuracy=0.8833333333333333
# k neighbors=27
# accuracy=0.9
# k neighbors=28
# accuracy=0.8833333333333333
# k neighbors=29
# accuracy=0.9
# k neighbors=30
# accuracy=0.8666666666666667
# k neighbors=31
# accuracy=0.9
# k neighbors=32
# accuracy=0.8666666666666667
# k neighbors=33
# accuracy=0.8833333333333333
# k neighbors=34
# accuracy=0.8666666666666667
# k neighbors=35
# accuracy=0.8833333333333333
# k neighbors=36
# accuracy=0.8666666666666667
# k neighbors=37
# accuracy=0.8833333333333333
# k neighbors=38
# accuracy=0.8666666666666667
# k neighbors=39
# accuracy=0.8666666666666667
# k neighbors=40
# accuracy=0.8666666666666667
# k neighbors=41
# accuracy=0.8333333333333334
# k neighbors=42
# accuracy=0.8166666666666667
# k neighbors=43
# accuracy=0.8166666666666667
# k neighbors=44
# accuracy=0.8166666666666667
# k neighbors=45
# accuracy=0.85
# k neighbors=46
# accuracy=0.8333333333333334
# k neighbors=47
# accuracy=0.85
# k neighbors=48
# accuracy=0.85
# k neighbors=49
# accuracy=0.85
# k neighbors=50
# accuracy=0.85
# k neighbors=51
# accuracy=0.8333333333333334
# k neighbors=52
# accuracy=0.8166666666666667
# k neighbors=53
# accuracy=0.8333333333333334
# k neighbors=54
# accuracy=0.8333333333333334
# k neighbors=55
# accuracy=0.8
# k neighbors=56
# accuracy=0.8
# k neighbors=57
# accuracy=0.8
# k neighbors=58
# accuracy=0.7833333333333333
# k neighbors=59
# accuracy=0.7666666666666667
# k neighbors=60
# accuracy=0.7666666666666667
# k neighbors=61
# accuracy=0.7666666666666667
# k neighbors=62
# accuracy=0.75
# k neighbors=63
# accuracy=0.75
# k neighbors=64
# accuracy=0.75
# k neighbors=65
# accuracy=0.75
# k neighbors=66
# accuracy=0.75
# k neighbors=67
# accuracy=0.75
# k neighbors=68
# accuracy=0.75
# k neighbors=69
# accuracy=0.75
# k neighbors=70
# accuracy=0.7333333333333333
# k neighbors=71
# accuracy=0.7333333333333333
# k neighbors=72
# accuracy=0.7333333333333333
# k neighbors=73
# accuracy=0.7333333333333333
# k neighbors=74
# accuracy=0.7166666666666667
# k neighbors=75
# accuracy=0.7166666666666667
# k neighbors=76
# accuracy=0.6833333333333333
# k neighbors=77
# accuracy=0.6666666666666666
# k neighbors=78
# accuracy=0.6333333333333333
# k neighbors=79
# accuracy=0.6333333333333333
# k neighbors=80
# accuracy=0.6
# k neighbors=81
# accuracy=0.6
# k neighbors=82
# accuracy=0.6
# k neighbors=83
# accuracy=0.6
# k neighbors=84
# accuracy=0.6
# k neighbors=85
# accuracy=0.26666666666666666
# k neighbors=86
# accuracy=0.26666666666666666
# k neighbors=87
# accuracy=0.26666666666666666
# k neighbors=88
# accuracy=0.26666666666666666
# k neighbors=89
# accuracy=0.26666666666666666
# k neighbors=90
# accuracy=0.26666666666666666
#
#
# best k=7
# best accuracy=0.9666666666666667
#
#  weighting:distance
# k neighbors=1
# accuracy=0.9166666666666666
# k neighbors=2
# accuracy=0.9166666666666666
# k neighbors=3
# accuracy=0.9333333333333333
# k neighbors=4
# accuracy=0.9166666666666666
# k neighbors=5
# accuracy=0.95
# k neighbors=6
# accuracy=0.9333333333333333
# k neighbors=7
# accuracy=0.9666666666666667
# k neighbors=8
# accuracy=0.9333333333333333
# k neighbors=9
# accuracy=0.9666666666666667
# k neighbors=10
# accuracy=0.9666666666666667
# k neighbors=11
# accuracy=0.9666666666666667
# k neighbors=12
# accuracy=0.9666666666666667
# k neighbors=13
# accuracy=0.9666666666666667
# k neighbors=14
# accuracy=0.95
# k neighbors=15
# accuracy=0.95
# k neighbors=16
# accuracy=0.9166666666666666
# k neighbors=17
# accuracy=0.9333333333333333
# k neighbors=18
# accuracy=0.9166666666666666
# k neighbors=19
# accuracy=0.9166666666666666
# k neighbors=20
# accuracy=0.9166666666666666
# k neighbors=21
# accuracy=0.9166666666666666
# k neighbors=22
# accuracy=0.9166666666666666
# k neighbors=23
# accuracy=0.9166666666666666
# k neighbors=24
# accuracy=0.9
# k neighbors=25
# accuracy=0.9166666666666666
# k neighbors=26
# accuracy=0.9166666666666666
# k neighbors=27
# accuracy=0.9333333333333333
# k neighbors=28
# accuracy=0.9333333333333333
# k neighbors=29
# accuracy=0.9333333333333333
# k neighbors=30
# accuracy=0.9166666666666666
# k neighbors=31
# accuracy=0.9333333333333333
# k neighbors=32
# accuracy=0.9166666666666666
# k neighbors=33
# accuracy=0.9333333333333333
# k neighbors=34
# accuracy=0.9166666666666666
# k neighbors=35
# accuracy=0.9333333333333333
# k neighbors=36
# accuracy=0.9166666666666666
# k neighbors=37
# accuracy=0.9333333333333333
# k neighbors=38
# accuracy=0.9
# k neighbors=39
# accuracy=0.9166666666666666
# k neighbors=40
# accuracy=0.9166666666666666
# k neighbors=41
# accuracy=0.9333333333333333
# k neighbors=42
# accuracy=0.9333333333333333
# k neighbors=43
# accuracy=0.9333333333333333
# k neighbors=44
# accuracy=0.9166666666666666
# k neighbors=45
# accuracy=0.9333333333333333
# k neighbors=46
# accuracy=0.9166666666666666
# k neighbors=47
# accuracy=0.9166666666666666
# k neighbors=48
# accuracy=0.9166666666666666
# k neighbors=49
# accuracy=0.9166666666666666
# k neighbors=50
# accuracy=0.9166666666666666
# k neighbors=51
# accuracy=0.9333333333333333
# k neighbors=52
# accuracy=0.9333333333333333
# k neighbors=53
# accuracy=0.9333333333333333
# k neighbors=54
# accuracy=0.9333333333333333
# k neighbors=55
# accuracy=0.9333333333333333
# k neighbors=56
# accuracy=0.95
# k neighbors=57
# accuracy=0.95
# k neighbors=58
# accuracy=0.95
# k neighbors=59
# accuracy=0.95
# k neighbors=60
# accuracy=0.95
# k neighbors=61
# accuracy=0.95
# k neighbors=62
# accuracy=0.95
# k neighbors=63
# accuracy=0.95
# k neighbors=64
# accuracy=0.95
# k neighbors=65
# accuracy=0.95
# k neighbors=66
# accuracy=0.95
# k neighbors=67
# accuracy=0.95
# k neighbors=68
# accuracy=0.95
# k neighbors=69
# accuracy=0.95
# k neighbors=70
# accuracy=0.95
# k neighbors=71
# accuracy=0.95
# k neighbors=72
# accuracy=0.95
# k neighbors=73
# accuracy=0.95
# k neighbors=74
# accuracy=0.95
# k neighbors=75
# accuracy=0.95
# k neighbors=76
# accuracy=0.95
# k neighbors=77
# accuracy=0.95
# k neighbors=78
# accuracy=0.95
# k neighbors=79
# accuracy=0.95
# k neighbors=80
# accuracy=0.95
# k neighbors=81
# accuracy=0.95
# k neighbors=82
# accuracy=0.95
# k neighbors=83
# accuracy=0.95
# k neighbors=84
# accuracy=0.95
# k neighbors=85
# accuracy=0.95
# k neighbors=86
# accuracy=0.95
# k neighbors=87
# accuracy=0.95
# k neighbors=88
# accuracy=0.95
# k neighbors=89
# accuracy=0.95
# k neighbors=90
# accuracy=0.95
#
#
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# Plot the Iris dataset, in 2-D, with a red color for Setosa, blu for Versicolor, Green for Virginica.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn import neighbors
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import tree
from sklearn.model_selection import GridSearchCV
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()

# %% [markdown]
# We choose the features petal length and petal width (corrispondig to index column: 2,3 respectively) because they produce the minor entropy value.

# %%
print(iris.feature_names)
_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 2], iris.data[:, 3], c=iris.target)
ax.set(xlabel=iris.feature_names[2], ylabel=iris.feature_names[3])
_ = ax.legend(scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes")
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ## What you have to do:
# 1. Plot the Iris dataset, in 2-D, with the color as above determined by the k-nn estimation

# %%
n_neighbors = 7
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')
clf_knn = clf_knn.fit(iris.data, iris.target)

predicted = clf_knn.predict(iris.data)

_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 2], iris.data[:, 3], c=predicted)
ax.set(xlabel=iris.feature_names[2], ylabel=iris.feature_names[3])
_ = ax.legend(scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes")

# %%
n_neighbors = 7
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf_knn = clf_knn.fit(iris.data, iris.target)

predicted = clf_knn.predict(iris.data)

_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 2], iris.data[:, 3], c=predicted)
ax.set(xlabel=iris.feature_names[2], ylabel=iris.feature_names[3])
_ = ax.legend(scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes")

# %% [markdown]
# 2. Plot the ROC plot of the k-nn (for the best value of k) for each of the three classes: setosa, virginica and versicolor
# 3. Plot the ROC plot for the best decision tree you trained in Exercize n.1
# 4. Compare decision trees and k-nn on the ROC space: for which values of (TPR,FPR) k-nn is better than decision trees?

# %%
n_neighbors = 7
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=300)
clf_knn.fit(X_train, y_train)

predicted_knn = clf_knn.predict(X_test)

fig, axs = plt.subplots(1,3,figsize=(20,5))
for j in range(3):
  fpr, tpr, _ = roc_curve(np.where(y_test==j, 1, -1), np.where(predicted_knn==j, 1, -1))
  count = 0
  for i in range(len(predicted_knn)):
    if(predicted_knn[i] == j):
      if(predicted_knn[i] != y_test[i]):
        count = count + 1
        print("exemplar: " + str(iris.data[i]) + ", predicted: " + str(predicted_knn[i]) + ", target: " + str(y_test[i]) + ", index: " + str(i))
  print(count)
  axs[j].plot(fpr, tpr, marker='o', linestyle='--')
  axs[j].set_title(f'Model: knn distance | Positive class: {iris.target_names[j]}')

#add the x and y axis legend
for ax in axs.flat:
    ax.set(xlabel='fpr', ylabel='tpr')

#adds space bewtween the subplots and shows them
fig.tight_layout()
fig.show()
# Out:
# 0
# exemplar: [5.7 3.8 1.7 0.3], predicted: 1, target: 2, index: 18
# 1
# exemplar: [5.  3.4 1.6 0.4], predicted: 2, target: 1, index: 26
# 1

# %%
clfTree = tree.DecisionTreeClassifier(criterion="entropy", random_state=300 ,min_samples_leaf=2, max_depth=3, max_leaf_nodes=4, min_impurity_decrease=0.1)
clfTree.fit(X_train, y_train)
predicted_tree = clfTree.predict(X_test)

fig, axs = plt.subplots(1,3,figsize=(20,5))
for j in range(3):
  fpr, tpr, _ = roc_curve(np.where(y_test==j, 1, -1), np.where(predicted_tree==j, 1, -1))
  count = 0
  for i in range(len(predicted_tree)):
    if(predicted_tree[i] == j):
      if(predicted_tree[i] != y_test[i]):
        count = count + 1
        print("exemplar: " + str(iris.data[i]) + ", predicted: " + str(predicted_tree[i]) + ", target: " + str(y_test[i]))
  print(count)
  axs[j].plot(fpr, tpr, marker='o', linestyle='--')
  axs[j].set_title(f'Model: decision tree | Positive class: {iris.target_names[j]}')

#add the x and y axis legend
for ax in axs.flat:
    ax.set(xlabel='fpr', ylabel='tpr')

#adds space bewtween the subplots and shows them
fig.tight_layout()
fig.show()
# Out:
# 0
# exemplar: [5.7 3.8 1.7 0.3], predicted: 1, target: 2
# exemplar: [4.7 3.2 1.6 0.2], predicted: 1, target: 2
# exemplar: [5.1 3.8 1.9 0.4], predicted: 1, target: 2
# 3
# 0

# %%
fig, axs = plt.subplots(1,3,figsize=(20,5))
for j in range(3):
  fpr_tree, tpr_tree, _ = roc_curve(np.where(y_test==j, 1, -1), np.where(predicted_tree==j, 1, -1))
  fpr_knn, tpr_knn, _ = roc_curve(np.where(y_test==j, 1, -1), np.where(predicted_knn==j, 1, -1))
  axs[j].plot(fpr_tree, tpr_tree, marker='o', linestyle='--', color = 'blue')
  axs[j].plot(fpr_knn, tpr_knn, marker='o', linestyle='--', color = 'red')
  axs[j].set_title(f'Model: decision tree & knn distance | Positive class: {iris.target_names[j]}')

#add the x and y axis legend
for ax in axs.flat:
    ax.set(xlabel='fpr', ylabel='tpr')
    plt.legend(['decision tree', 'knn distance'])
    ax.scatter(0, 1, c='green')

#adds space bewtween the subplots and shows them
fig.tight_layout()
fig.show()

# - both of the models classify the setosa's examples
# - knn classifies better than decision tree the versicolor's examples (knn makas 1 error insted of 3 error of decision tree) because
#    the distance between the best point in the ROC heaven (0,1) and the knn's point is the smallest
# - knn classifies better than decision tree the virginica's examples (knn makas 1 error insted of 3 error of decision tree) because
#    the distance between the best point in the ROC heaven (0,1) and the knn's point is the smallest

# %% [markdown]
# 5. In the following, extend the above exercize on k-nn using a kernel function
# K(x,y) for the distances computation, such that distance(x,y)=1-K(x,y).    Use a Gaussian-like (or Radial Basis Function) kernel K(x,y)=exp(-gamma(x-y)^2), with gamma the inverse of the sigma squared variance, that must be tuned to the best value according to the accuracy reached by the k-nn, with k=7 (similarly as done with the previous example on tuning the parameter n_neightbors).

# %%
def distance(x,y,gamma):
  return 1 - (np.exp(-gamma * (np.linalg.norm(x-y, ord=2) ** 2)))

# %%
n_neighbors = 7

array_dicts = []
for g in np.arange(1,100):
   array_dicts.append({'gamma':g})
parameters = {'n_neighbors': [n_neighbors], 'weights': ['distance'], 'metric': [distance], 'metric_params': array_dicts}

clf_knn_kernel = neighbors.KNeighborsClassifier()
grid = GridSearchCV(clf_knn_kernel, parameters, scoring='accuracy', cv=5)
grid.fit(iris.data, iris.target)
print("The best params are: " + str(grid.best_params_))
print("with the mean accuracy: " + str(grid.best_score_))
print("the best gamma is: " + str(grid.best_params_['metric_params']))

pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

data = pd.DataFrame({'param': grid.cv_results_["params"], 'acc': grid.cv_results_["mean_test_score"]})
data
# Out:
# The best params are: {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 2}, 'n_neighbors': 7, 'weights': 'distance'}
# with the mean accuracy: 0.9800000000000001
# the best gamma is: {'gamma': 2}
#                                                                                                                          param  \
# 0    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 1}, 'n_neighbors': 7, 'weights': 'distance'}
# 1    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 2}, 'n_neighbors': 7, 'weights': 'distance'}
# 2    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 3}, 'n_neighbors': 7, 'weights': 'distance'}
# 3    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 4}, 'n_neighbors': 7, 'weights': 'distance'}
# 4    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 5}, 'n_neighbors': 7, 'weights': 'distance'}
# 5    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 6}, 'n_neighbors': 7, 'weights': 'distance'}
# 6    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 7}, 'n_neighbors': 7, 'weights': 'distance'}
# 7    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 8}, 'n_neighbors': 7, 'weights': 'distance'}
# 8    {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 9}, 'n_neighbors': 7, 'weights': 'distance'}
# 9   {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 10}, 'n_neighbors': 7, 'weights': 'distance'}
# 10  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 11}, 'n_neighbors': 7, 'weights': 'distance'}
# 11  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 12}, 'n_neighbors': 7, 'weights': 'distance'}
# 12  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 13}, 'n_neighbors': 7, 'weights': 'distance'}
# 13  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 14}, 'n_neighbors': 7, 'weights': 'distance'}
# 14  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 15}, 'n_neighbors': 7, 'weights': 'distance'}
# 15  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 16}, 'n_neighbors': 7, 'weights': 'distance'}
# 16  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 17}, 'n_neighbors': 7, 'weights': 'distance'}
# 17  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 18}, 'n_neighbors': 7, 'weights': 'distance'}
# 18  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 19}, 'n_neighbors': 7, 'weights': 'distance'}
# 19  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 20}, 'n_neighbors': 7, 'weights': 'distance'}
# 20  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 21}, 'n_neighbors': 7, 'weights': 'distance'}
# 21  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 22}, 'n_neighbors': 7, 'weights': 'distance'}
# 22  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 23}, 'n_neighbors': 7, 'weights': 'distance'}
# 23  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 24}, 'n_neighbors': 7, 'weights': 'distance'}
# 24  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 25}, 'n_neighbors': 7, 'weights': 'distance'}
# 25  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 26}, 'n_neighbors': 7, 'weights': 'distance'}
# 26  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 27}, 'n_neighbors': 7, 'weights': 'distance'}
# 27  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 28}, 'n_neighbors': 7, 'weights': 'distance'}
# 28  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 29}, 'n_neighbors': 7, 'weights': 'distance'}
# 29  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 30}, 'n_neighbors': 7, 'weights': 'distance'}
# 30  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 31}, 'n_neighbors': 7, 'weights': 'distance'}
# 31  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 32}, 'n_neighbors': 7, 'weights': 'distance'}
# 32  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 33}, 'n_neighbors': 7, 'weights': 'distance'}
# 33  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 34}, 'n_neighbors': 7, 'weights': 'distance'}
# 34  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 35}, 'n_neighbors': 7, 'weights': 'distance'}
# 35  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 36}, 'n_neighbors': 7, 'weights': 'distance'}
# 36  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 37}, 'n_neighbors': 7, 'weights': 'distance'}
# 37  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 38}, 'n_neighbors': 7, 'weights': 'distance'}
# 38  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 39}, 'n_neighbors': 7, 'weights': 'distance'}
# 39  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 40}, 'n_neighbors': 7, 'weights': 'distance'}
# 40  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 41}, 'n_neighbors': 7, 'weights': 'distance'}
# 41  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 42}, 'n_neighbors': 7, 'weights': 'distance'}
# 42  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 43}, 'n_neighbors': 7, 'weights': 'distance'}
# 43  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 44}, 'n_neighbors': 7, 'weights': 'distance'}
# 44  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 45}, 'n_neighbors': 7, 'weights': 'distance'}
# 45  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 46}, 'n_neighbors': 7, 'weights': 'distance'}
# 46  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 47}, 'n_neighbors': 7, 'weights': 'distance'}
# 47  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 48}, 'n_neighbors': 7, 'weights': 'distance'}
# 48  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 49}, 'n_neighbors': 7, 'weights': 'distance'}
# 49  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 50}, 'n_neighbors': 7, 'weights': 'distance'}
# 50  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 51}, 'n_neighbors': 7, 'weights': 'distance'}
# 51  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 52}, 'n_neighbors': 7, 'weights': 'distance'}
# 52  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 53}, 'n_neighbors': 7, 'weights': 'distance'}
# 53  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 54}, 'n_neighbors': 7, 'weights': 'distance'}
# 54  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 55}, 'n_neighbors': 7, 'weights': 'distance'}
# 55  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 56}, 'n_neighbors': 7, 'weights': 'distance'}
# 56  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 57}, 'n_neighbors': 7, 'weights': 'distance'}
# 57  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 58}, 'n_neighbors': 7, 'weights': 'distance'}
# 58  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 59}, 'n_neighbors': 7, 'weights': 'distance'}
# 59  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 60}, 'n_neighbors': 7, 'weights': 'distance'}
# 60  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 61}, 'n_neighbors': 7, 'weights': 'distance'}
# 61  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 62}, 'n_neighbors': 7, 'weights': 'distance'}
# 62  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 63}, 'n_neighbors': 7, 'weights': 'distance'}
# 63  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 64}, 'n_neighbors': 7, 'weights': 'distance'}
# 64  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 65}, 'n_neighbors': 7, 'weights': 'distance'}
# 65  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 66}, 'n_neighbors': 7, 'weights': 'distance'}
# 66  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 67}, 'n_neighbors': 7, 'weights': 'distance'}
# 67  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 68}, 'n_neighbors': 7, 'weights': 'distance'}
# 68  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 69}, 'n_neighbors': 7, 'weights': 'distance'}
# 69  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 70}, 'n_neighbors': 7, 'weights': 'distance'}
# 70  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 71}, 'n_neighbors': 7, 'weights': 'distance'}
# 71  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 72}, 'n_neighbors': 7, 'weights': 'distance'}
# 72  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 73}, 'n_neighbors': 7, 'weights': 'distance'}
# 73  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 74}, 'n_neighbors': 7, 'weights': 'distance'}
# 74  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 75}, 'n_neighbors': 7, 'weights': 'distance'}
# 75  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 76}, 'n_neighbors': 7, 'weights': 'distance'}
# 76  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 77}, 'n_neighbors': 7, 'weights': 'distance'}
# 77  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 78}, 'n_neighbors': 7, 'weights': 'distance'}
# 78  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 79}, 'n_neighbors': 7, 'weights': 'distance'}
# 79  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 80}, 'n_neighbors': 7, 'weights': 'distance'}
# 80  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 81}, 'n_neighbors': 7, 'weights': 'distance'}
# 81  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 82}, 'n_neighbors': 7, 'weights': 'distance'}
# 82  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 83}, 'n_neighbors': 7, 'weights': 'distance'}
# 83  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 84}, 'n_neighbors': 7, 'weights': 'distance'}
# 84  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 85}, 'n_neighbors': 7, 'weights': 'distance'}
# 85  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 86}, 'n_neighbors': 7, 'weights': 'distance'}
# 86  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 87}, 'n_neighbors': 7, 'weights': 'distance'}
# 87  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 88}, 'n_neighbors': 7, 'weights': 'distance'}
# 88  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 89}, 'n_neighbors': 7, 'weights': 'distance'}
# 89  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 90}, 'n_neighbors': 7, 'weights': 'distance'}
# 90  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 91}, 'n_neighbors': 7, 'weights': 'distance'}
# 91  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 92}, 'n_neighbors': 7, 'weights': 'distance'}
# 92  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 93}, 'n_neighbors': 7, 'weights': 'distance'}
# 93  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 94}, 'n_neighbors': 7, 'weights': 'distance'}
# 94  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 95}, 'n_neighbors': 7, 'weights': 'distance'}
# 95  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 96}, 'n_neighbors': 7, 'weights': 'distance'}
# 96  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 97}, 'n_neighbors': 7, 'weights': 'distance'}
# 97  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 98}, 'n_neighbors': 7, 'weights': 'distance'}
# 98  {'metric': <function distance at 0x7ac487166d40>, 'metric_params': {'gamma': 99}, 'n_neighbors': 7, 'weights': 'distance'}
#
#          acc
# 0   0.973333
# 1   0.980000
# 2   0.980000
# 3   0.973333
# 4   0.980000
# 5   0.980000
# 6   0.980000
# 7   0.980000
# 8   0.980000
# 9   0.980000
# 10  0.980000
# 11  0.980000
# 12  0.980000
# 13  0.980000
# 14  0.980000
# 15  0.980000
# 16  0.980000
# 17  0.980000
# 18  0.980000
# 19  0.980000
# 20  0.980000
# 21  0.980000
# 22  0.980000
# 23  0.980000
# 24  0.980000
# 25  0.980000
# 26  0.980000
# 27  0.980000
# 28  0.980000
# 29  0.980000
# 30  0.980000
# 31  0.980000
# 32  0.980000
# 33  0.980000
# 34  0.980000
# 35  0.973333
# 36  0.973333
# 37  0.966667
# 38  0.966667
# 39  0.966667
# 40  0.966667
# 41  0.966667
# 42  0.966667
# 43  0.960000
# 44  0.960000
# 45  0.960000
# 46  0.960000
# 47  0.960000
# 48  0.960000
# 49  0.960000
# 50  0.960000
# 51  0.960000
# 52  0.960000
# 53  0.960000
# 54  0.960000
# 55  0.953333
# 56  0.953333
# 57  0.946667
# 58  0.946667
# 59  0.946667
# 60  0.946667
# 61  0.946667
# 62  0.946667
# 63  0.946667
# 64  0.946667
# 65  0.946667
# 66  0.946667
# 67  0.946667
# 68  0.946667
# 69  0.940000
# 70  0.940000
# 71  0.926667
# 72  0.926667
# 73  0.920000
# 74  0.906667
# 75  0.906667
# 76  0.900000
# 77  0.900000
# 78  0.900000
# 79  0.900000
# 80  0.900000
# 81  0.886667
# 82  0.886667
# 83  0.886667
# 84  0.886667
# 85  0.886667
# 86  0.886667
# 87  0.886667
# 88  0.886667
# 89  0.880000
# 90  0.880000
# 91  0.873333
# 92  0.873333
# 93  0.873333
# 94  0.873333
# 95  0.860000
# 96  0.860000
# 97  0.860000
# 98  0.860000
